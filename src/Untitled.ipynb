# %%
import run_kmedian as rk

# %%
rk.run_kmedian('../test','../train','../solution')
# Out:
# no date 2013-07-01 in file ../train/6165_air_weekday_out.csv
# no date 2013-07-01 in file ../train/821_air_weekday_out.csv
# solution for 2013-07-01 air [ 0.  0.  0. ...,  0.  0.  0.]
# no date 2013-07-01 in file ../train/6165_dryer_weekday_out.csv
# no date 2013-07-01 in file ../train/821_dryer_weekday_out.csv
# solution for 2013-07-01 dryer [ 0.  0.  0. ...,  0.  0.  0.]
# no date 2013-07-01 in file ../train/6165_furnace_weekday_out.csv
# no date 2013-07-01 in file ../train/821_furnace_weekday_out.csv
# solution for 2013-07-01 furnace [ 0.401  0.401  0.401 ...,  0.402  0.402  0.402]
# no date 2013-07-01 in file ../train/6165_lights_plugs_weekday_out.csv
# no date 2013-07-01 in file ../train/821_lights_plugs_weekday_out.csv
# solution for 2013-07-01 lights_plugs [ 0.5    0.496  0.491 ...,  0.4    0.462  0.503]
# no date 2013-07-01 in file ../train/6165_refrigerator_weekday_out.csv
# no date 2013-07-01 in file ../train/821_refrigerator_weekday_out.csv
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('../train/6165_air_weekday_out.csv')
df.head(20)
# Out:
#           Date  00:00:00  00:01:00  00:02:00  00:03:00  00:04:00  00:05:00  \
# 0   2013-08-19     0.004     0.004     0.670     1.983     2.006     2.012
# 1   2013-08-20     0.004     0.004     0.004     0.004     0.004     0.004
# 2   2013-08-21     0.004     0.004     0.004     0.004     0.004     0.004
# 3   2013-08-22     0.004     0.004     0.004     0.003     0.003     0.004
# 4   2013-08-23     2.054     2.048     2.048     2.041     2.044     2.044
# 5   2013-08-26     1.958     1.961     1.969     1.980     1.978     1.981
# 6   2013-08-27     0.004     0.004     0.004     0.004     0.004     0.004
# 7   2013-08-28     1.820     1.441     0.004     0.004     0.004     0.004
# 8   2013-08-29     2.008     2.018     2.009     2.010     2.005     2.006
# 9   2013-08-30     0.004     0.004     0.004     0.004     0.004     0.004
# 10  2013-09-02     2.053     2.052     2.052     2.054     2.050     2.046
# ...
